# %%
import gzip
from IPython.display import display, clear_output


contributions_xml = gzip.open('data/dblp.xml.gz','r')

# %%
types = ['article','inproceedings','www','proceedings','book','incollection','phdthesis','mastersthesis','www']
contributions =  {t:[] for t in types}
begin = False

for key,line in enumerate(contributions_xml):
    line = str(line)
    for t in types:
        if '</' + t in line:
            begin = False
            contributions[t].append(contribution)
            break
    
    if begin:
        if '<' in line:
            vals = line.replace('<','>').split('>')
            vals[1] = vals[1].split(' ')[0]
            if vals[1] in contribution:
                contribution[vals[1]] += ', ' + vals[2]
            else:
                contribution[vals[1]] = vals[2]
            
    for t in types:
        if '<' + t in line:
            begin = True
            contribution = {}
            break

    if key % 50000 == 0 and key != 0:
        clear_output(wait=True)
        print("Imported: {}".format(sum([len(contributions[t]) for t in types])))
# Out:
# Imported: 11616873

# %%
contributions['article'][1000]
# Out:
# {'author': 'Bin Zhang 0004, Meichun Hsu',
#  'title': 'Unsafe Operations in B-Trees.',
#  'pages': '421-438',
#  'year': '1989',
#  'volume': '26',
#  'journal': 'Acta Inf.',
#  'number': '5',
#  'url': 'db/journals/acta/acta26.html#ZhangH89',
#  'ee': 'https://doi.org/10.1007/BF00289145'}

# %%
import pandas as pd

articles = pd.DataFrame.from_dict(contributions['article'])

# %%
len(articles)
# Out:
# 2022302

# %%
articles_f = articles[['author','title','year']].dropna()
len(articles_f)
# Out:
# 2010439

# %%
articles_f.describe()
# Out:
#                    author       title     year
# count             2010439     2010439  2010439
# unique            1531348     1965048       85
# top     T. D. Wilson 0001  Editorial.     2018
# freq                  337        4668   174846

# %%
articles_f['author'] = articles_f['author'].str.replace('\d+', '').replace('&+','').replace(';+','')

articles_f.sample(1000)
# Out:
#                                                     author  \
# 1446848                         Katarina Mele, Jasna Maver
# 998150   Wenze Yang, Bin Tan, Dong Huang, Miina Rautiai...
# 679442                        Pardeep Kumar, Hoon-Jae Lee
# 1950843     Orit E. Raz, Oliver Roche-Newton, Micha Sharir
# 1715798                 Ingo Alth&ouml;fer, Susanne Heuser
# 627682                               Michael Jay Schillaci
# 1881991  Amenah H. Abdulateef, Bara'a A. Attea, Ahmed N...
# 699889      David P. Varodayan, Yao-Chung Lin, Bernd Girod
# 960019   Ayon Sen, Md. Monirul Islam, Kazuyuki Murase, ...
# 1987204  Joseph Vinish D'silva, Florestant De Moor, Bet...
# 510821                                   Reuben S. Dlamini
# 1457489         K. T. Arasu, Grady Burkett, Michael Linger
# 776035                             Dizza Beimel, Mor Peleg
# 997812                           K. J. Boo, Nirmal K. Bose
# 271942   Chris Fox, Maribel Fern&aacute;ndez, Shalom La...
# 1212185                    Abhishek Agarwal, Arya Mazumdar
# 1050652                  Hao Liao, An Zeng, Yi-Cheng Zhang
# 1890212         Rebecca L. Casta&ntilde;o, Seth Hutchinson
# 1950843  Sets with few distinct distances do not have h...  2015
# 1715798     Randomised Evaluations in Single-Agent Search.  2005
# 627682                                  Maximum Mechanics.  2016
# 1881991  A new evolutionary algorithm with locally assi...  2018
# 699889                 Adaptive Distributed Source Coding.  2012
# 960019   Binarization With Boosting and Oversampling fo...  2016
# 1987204  AIDA - Abstraction for Advanced In-Database An...  2018
# 510821   The role of the strategic and adaptive Chief I...  2015
# 1457489  Existence Status of Some Previously Open Abeli...  2003
# 776035   Using OWL and SWRL to represent and reason wit...  2011
# 997812   Multispectral image restoration with multisens...  1997
# 271942   Lambda Calculus, Type Theory, and Natural Lang...  2008
# 1212185      Local Partial Clique Covers for Index Coding.  2016
# 1050652  Towards an objective ranking in online reputat...  2014
# 1890212   A Probabilistic Approach to Perceptual Grouping.  1996
# 1966627  Separation of concerns for evolving systems: a...  2005
# 959769                      Harmonious Genetic Clustering.  2018
# 1996479  Monitoring drinking behavior in bucket-fed dai...  2018
# 1299932  The characteristics of gifted students' ecolog...  2012
# 136025   Enhanced bootstrapped CMOS driver for large RC...  2012
# 1648081  Learning from Multiple Sources via Multiple Do...  2016
# 303259   The need for a science of engineering informat...  2007
# 1767979        Extremal minimality conditions on automata.  2012
# 1992127  Optimized frequency-based foundation design fo...  2011
# 204326   Automated semantic elaboration of web site inf...  2008
# 1628266  Multiple Description Video Coding Based on Hum...  2014
# 1782114  A Low Complexity Resource Allocation Method fo...  2013
# ...                                                    ...   ...
# 1304184  Mixed finite element analysis for the Poisson-...  2018
# 872775   Sets of Periods for Piecewise Monotone Tree Maps.  2003
# 274660   A Geographically Weighted Regression Analysis ...  2018
# 835074   The SAP HANA Database -- An Architecture Overv...  2012
# 1362424  Closed-Loop Behavior of a Feedback-Controlled ...  1991
# 1189875  Context-Aware Query Selection for Active Learn...  2019
# 1951228       Hall sets, Lazard sets and comma-free codes.  2018
# 588152   Cryptanalysis of Bohio et al.'s ID-Based Broad...  2008
# 1382767  BioThesaurus: a web-based thesaurus of protein...  2006
# 141419   Principles and Implementation Techniques of So...  2017
# 1334153  A Framework for Web Content Management System ...  2008
# 1119346                    When is tit-for-tat unbeatable?  2013
# 765041   A Parallel-Serial Binary Arbitration Scheme fo...  1988
# 1669463                    Optimal rectangular partitions.  2003
# 449679   The implementation of a dynamic management sch...  1998
# 1553932       Cloud Mobile Media: Reflections and Outlook.  2014
# 1593054  Vertex-Partitioning into Fixed Additive Induce...  2004
# 1179085  Erd&#337;s-Szekeres and Testing Weak epsilon-N...  2011
# 1475581  Older Adults and Video Communications: A Case ...  2012
# 328733   A Computational Study on Circuit Size versus C...  2006
# 926927    Equivalence Relations which are Borel Somewhere.  2017
# 1797878  Conversion of descriptor representations to st...  2018
# 1311506  Antecedents and consequences of cyberloafing: ...  2017
# 1559899  Collision-Free Access Control for Computer Com...  1981
# 974519   EasiDSlT: A Two-Layer Data Association Method ...  2015
# 875201                  Coloring Powers of Chordal Graphs.  2004
# 1654568  Using In-Memory Analytics to Quickly Crunch Bi...  2012
# 1988540                BF-Tree: Approximate Tree Indexing.  2014
# 1316297  Energetic and Informational Masking Effects in...  2009
# 1317965  Interactive Spoken Document Retrieval With Sug...  2012
#
# [1000 rows x 3 columns]

# %%
years = articles_f.groupby('year').count()
years
# Out:
#       author   title
# year
# 1936      12      12
# 1937      15      15
# 1938      10      10
# 1939      18      18
# 1940      10      10
# 1941      13      13
# 1942      13      13
# 1943       8       8
# 1944       5       5
# 1945       9       9
# 1946      31      31
# 1947      10      10
# 1948      15      15
# 1949      23      23
# 1950      24      24
# 1951      19      19
# 1952      34      34
# 1953     110     110
# 1954     158     158
# 1955     149     149
# 1956     206     206
# 1957     241     241
# 1958     267     267
# 1959     373     373
# 1960     413     413
# 1961     599     599
# 1962     787     787
# 1963     781     781
# 1964     751     751
# 1965     876     876
# ...      ...     ...
# 1991   13371   13371
# 1992   14850   14850
# 1993   16712   16712
# 1994   18375   18375
# 1995   19993   19993
# 1996   22203   22203
# 1997   22994   22994
# 1998   25681   25681
# 1999   28292   28292
# 2000   33057   33057
# 2001   34611   34611
# 2002   36825   36825
# 2003   42458   42458
# 2004   46854   46854
# 2005   55209   55209
# 2006   62824   62824
# 2007   70140   70140
# 2008   75314   75314
# 2009   83033   83033
# 2010   89848   89848
# 2011   96571   96571
# 2012  105381  105381
# 2013  112792  112792
# 2014  119922  119922
# 2015  125255  125255
# 2016  135829  135829
# 2017  151270  151270
# 2018  174846  174846
# 2019   61516   61516
# 2020       1       1
#
# [85 rows x 2 columns]

# %%
import nltk 
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

stop_words = set(stopwords.words('english'))
lem = WordNetLemmatizer()

# %%
from collections import Counter
import string

frequencies = {}
for year in years.index:
    frequencies[year] = Counter()
    for key,title in enumerate(articles_f[articles_f['year'] == year]['title']):
        for word in title.replace('\n',' ').split(' '):
            filtered_word = word.lower().translate(str.maketrans('', '', string.punctuation))
            if filtered_word not in stop_words:
                filtered_word = lem.lemmatize(filtered_word,"v")
                frequencies[year][filtered_word] += 1
    if int(year) % 5 == 0:
        clear_output(wait=True)
        print("{}".format(year))
# Out:
# 1940

# %%
import wordcloud 
import matplotlib.pyplot as plt

def generate_word_cloud(freq):
    for key in ['2000']:
        try:
            wc = wordcloud.WordCloud(background_color="white", max_words=250, width=800, height=400)
            wc.generate_from_frequencies(frequencies=freq[key])
            plt.figure(figsize=(20,10))
            plt.imshow(wc, interpolation="bilinear")
            plt.axis("off")
            plt.savefig("results/" + key + '.png', bbox_inches='tight',dpi = 200)
        except:
            print(key)

# %%
generate_word_cloud(frequencies)

# %%
articles_f.groupby('year')['title']
